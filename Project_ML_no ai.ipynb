# %% [markdown]
# LOAD DATASET ===================================================

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Replace 'your_file_path_here.csv' with the actual path to your CSV file in Google Drive
# Example: '/content/drive/MyDrive/my_folder/my_data.csv'
file_path = '/content/drive/MyDrive/Colab Notebooks/Kumpulan dataset/hantavirusdetection.csv'

try:
    df = pd.read_csv(file_path)
    print("CSV file loaded successfully!")
    print(df.head()) # Display the first few rows of the DataFrame
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found. Please check the path.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CSV file loaded successfully!
#    Hantavirus_Positive  Age  WBC_Count_K/uL  Platelet_Count_K/uL  CRP_mg/L  \
# 0                    0   69            7.42               290.42      3.26
# 1                    0   76            8.43               228.22      5.33
# 2                    0   61            7.48               194.26      0.10
# 3                    0   57            4.25               216.26      3.46
# 4                    1   25            5.26               174.40     74.38
#
#    ALT_U/L  AST_U/L  BUN_mg/dL  Creatinine_mg/dL
# 0     22.1     24.7       10.6              0.38
# 1     12.7     41.8       13.2              0.84
# 2     14.3     38.1       20.6              1.05
# 3     29.3     30.0        5.5              0.74
# 4     45.7    133.0       60.9              2.56

# %% [markdown]
# EXPLORATORY DATA ANALYSIS =====================================

# %% [markdown]
# Tipe Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Hantavirus_Positive  10000 non-null  int64
#  1   Age                  10000 non-null  int64
#  2   WBC_Count_K/uL       10000 non-null  float64
#  3   Platelet_Count_K/uL  10000 non-null  float64
#  4   CRP_mg/L             10000 non-null  float64
#  5   ALT_U/L              10000 non-null  float64
#  6   AST_U/L              10000 non-null  float64
#  7   BUN_mg/dL            10000 non-null  float64
#  8   Creatinine_mg/dL     10000 non-null  float64
# dtypes: float64(7), int64(2)
# memory usage: 703.3 KB

# %% [markdown]
# Pie Chart

# %%
import matplotlib.pyplot as plt  # Mengimpor library matplotlib.pyplot untuk membuat visualisasi grafik
import pandas as pd  # Mengimpor library pandas untuk pengolahan data

hantavirus_counts = df['Hantavirus_Positive'].value_counts()
print(hantavirus_counts)
plt.pie(hantavirus_counts, autopct='%1.1f%%')
plt.title('hantavirus')
plt.show()
# Out:
# Hantavirus_Positive
# 0    7429
# 1    2571
# Name: count, dtype: int64

# %% [markdown]
# Histogram

# %%
df_numerik=df.drop(columns=['Hantavirus_Positive'])
df_numerik
df_numerik.hist(figsize=(50, 30))
plt.show()

# %% [markdown]
# Boxplot

# %%
df_numerik
df_numerik.boxplot(figsize=(20, 20))
plt.show()

# %%
df_y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Hantavirus_Positive, Length: 10000, dtype: int64

# %% [markdown]
# Scatter Plot

# %%
import matplotlib.pyplot as plt
df_x = df_numerik
df_y = df['Hantavirus_Positive']

# Fix: Select a specific column from df_numerik for the x-axis
# For example, let's plot 'Age' against 'Hantavirus_Positive'
plt.scatter(df_x['Age'],df_y)
plt.xlabel('Age')
plt.ylabel('Hantavirus_Positive')
plt.title('Scatter Plot of Age vs Hantavirus_Positive')
plt.show()

plt.scatter(df_x['WBC_Count_K/uL'],df_y)
plt.xlabel('WBC_Count_K/uL')
plt.ylabel('Hantavirus_Positive')
plt.title('Scatter Plot of WBC_Count_K/uL vs Hantavirus_Positive')
plt.show()

plt.scatter(df_x['Platelet_Count_K/uL'],df_y)
plt.xlabel('Platelet_Count_K/uL')
plt.ylabel('Hantavirus_Positive')
plt.title('Scatter Plot of Platelet_Count_K/uL vs Hantavirus_Positive')
plt.show()

plt.scatter(df_x['ALT_U/L'],df_y)
plt.xlabel('ALT_U/L')
plt.ylabel('Hantavirus_Positive')
plt.title('Scatter Plot of ALT_U/L vs Hantavirus_Positive')
plt.show()

plt.scatter(df_x['AST_U/L'],df_y)
plt.xlabel('AST_U/L')
plt.ylabel('Hantavirus_Positive')
plt.title('Scatter Plot of AST_U/L vs Hantavirus_Positive')
plt.show()

plt.scatter(df_x['BUN_mg/dL'],df_y)
plt.xlabel('BUN_mg/dL')
plt.ylabel('Hantavirus_Positive')
plt.title('Scatter Plot of BUN_mg/dL vs Hantavirus_Positive')
plt.show()

plt.scatter(df_x['Creatinine_mg/dL'],df_y)
plt.xlabel(' Creatinine_mg/dL')
plt.ylabel('Hantavirus_Positive')
plt.title('Scatter Plot of  Creatinine_mg/dL vs Hantavirus_Positive')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of  Creatinine_mg/dL vs Hantavirus_Positive')

# %% [markdown]
# Heatmap Korelasi

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = df.corr();corr
plt.figure(figsize=(10,10))
sns.heatmap(corr, annot=True)
plt.title("Heatmap Korelasi")
plt.show()

# %% [markdown]
# Missing Value dan Duplikasi

# %%
print("--------------------missing value---------------")
print(df.isnull().sum())
print("--------------------duplikat nya adalah--------------------")
print(df.duplicated().sum())
# Out:
# --------------------missing value---------------
# Hantavirus_Positive    0
# Age                    0
# WBC_Count_K/uL         0
# Platelet_Count_K/uL    0
# CRP_mg/L               0
# ALT_U/L                0
# AST_U/L                0
# BUN_mg/dL              0
# Creatinine_mg/dL       0
# dtype: int64
# --------------------duplikat nya adalah--------------------
# 0

# %% [markdown]
# PRAPEMEMROSESAN DAN REKAYASA FITUR =========================================

# %% [markdown]
# Standarisasi

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_standarisasi = scaler.fit_transform(df_numerik)
df_standarisasi = pd.DataFrame(df_standarisasi, columns=df_numerik.columns)
print("Sebelum Standarisasi")
df_numerik
# Out:
# Sebelum Standarisasi
#       Age  WBC_Count_K/uL  Platelet_Count_K/uL  CRP_mg/L  ALT_U/L  AST_U/L  \
# 0      69            7.42               290.42      3.26     22.1     24.7
# 1      76            8.43               228.22      5.33     12.7     41.8
# 2      61            7.48               194.26      0.10     14.3     38.1
# 3      57            4.25               216.26      3.46     29.3     30.0
# 4      25            5.26               174.40     74.38     45.7    133.0
# ...   ...             ...                  ...       ...      ...      ...
# 9995   61            5.37               242.37      9.22     31.6      5.0
# 9996   39            6.36               251.11      3.43     47.5     34.1
# 9997   45            7.27               276.09      2.88     46.4     50.4
# 9998   34            8.08               240.01      9.80     39.4     27.6
# 9999   52            7.23               267.12      5.66     68.5     59.4
#
#       BUN_mg/dL  Creatinine_mg/dL
# ...

# %%
print("Standarisasi Data")
df_standarisasi
# Out:
# Standarisasi Data
#            Age  WBC_Count_K/uL  Platelet_Count_K/uL  CRP_mg/L   ALT_U/L  \
# 0     0.923625        0.137309             1.103337 -0.598093 -0.694248
# 1     1.285195        0.696680            -0.084407 -0.496937 -0.984245
# 2     0.510403        0.170539            -0.732893 -0.752514 -0.934884
# 3     0.303791       -1.618339            -0.312790 -0.588319 -0.472122
# 4    -1.349100       -1.058969            -1.112131  2.877367  0.033832
# ...        ...             ...                  ...       ...       ...
# 9995  0.510403       -0.998047             0.185795 -0.306842 -0.401165
# 9996 -0.625960       -0.449753             0.352690 -0.589785  0.089364
# 9997 -0.316043        0.054235             0.829698 -0.616662  0.055428
# 9998 -0.884225        0.502839             0.140730 -0.278499 -0.160528
# 9999  0.045527        0.032081             0.658411 -0.480810  0.737231
#
#        AST_U/L  BUN_mg/dL  Creatinine_mg/dL
# ...

# %% [markdown]
# Menggunakan 5 Fitur Terbaik

# %%
from xgboost import XGBClassifier #mengimpor model XGBClassifier dari library xgboost
import pandas as pd #mengimpor library pandas untuk pengolahan data
model_feature = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
model_feature.fit(df_standarisasi, df['Hantavirus_Positive'])
importances = model_feature.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': df_standarisasi.columns, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print(feature_importance_df)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [07:50:56] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#                Feature  Importance
# 3             CRP_mg/L    0.905601
# 7     Creatinine_mg/dL    0.044654
# 4              ALT_U/L    0.031321
# 5              AST_U/L    0.007188
# 6            BUN_mg/dL    0.005837
# 2  Platelet_Count_K/uL    0.003454
# 1       WBC_Count_K/uL    0.001177
# 0                  Age    0.000767

# %%
df_5fitur = df_standarisasi[['CRP_mg/L','Creatinine_mg/dL','ALT_U/L','AST_U/L','BUN_mg/dL']]
df_5fitur
# Out:
#       CRP_mg/L  Creatinine_mg/dL   ALT_U/L   AST_U/L  BUN_mg/dL
# 0    -0.598093         -1.116831 -0.694248 -0.713875  -0.955934
# 1    -0.496937         -0.494596 -0.984245 -0.236693  -0.744577
# 2    -0.752514         -0.210532 -0.934884 -0.339943  -0.143021
# 3    -0.588319         -0.629864 -0.472122 -0.565976  -1.370520
# 4     2.877367          1.832022  0.033832  2.308275   3.133021
# ...        ...               ...       ...       ...        ...
# 9995 -0.306842         -1.143884 -0.401165 -1.263610  -1.411166
# 9996 -0.589785         -0.251112  0.089364 -0.451564  -0.541348
# 9997 -0.616662         -0.048210  0.055428  0.003293  -0.630769
# 9998 -0.278499         -0.859821 -0.160528 -0.632949   0.206532
# 9999 -0.480810         -0.359327  0.737231  0.254441  -1.151034
#
# [10000 rows x 5 columns]

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_5fitur, df['Hantavirus_Positive'], test_size=0.2, random_state=42,stratify= df_y)

print(f"Jumlah X_train: {X_train.shape}") #menampilkan ukuran data fitur training
print(f"Jumlah X_test: {X_test.shape}") #menampilkan ukuran data fitur testing
print(f"Jumlah y_train: {y_train.shape}") #menampilkan ukuran data target training
print(f"Jumlah y_test: {y_test.shape}") #menampilkan ukuran data target testing

print("\nratio y_train (stratified):") #menampilkan distribusi kelas target pada data training
print(y_train.value_counts(normalize=True)) #menghitung proporsi masing-masing kelas pada y_train

print("\nratio y_test (stratified):") #menampilkan distribusi kelas target pada data testing
print(y_test.value_counts(normalize=True)) #menghitung proporsi masing-masing kelas pada y_test
# Out:
# Jumlah X_train: (8000, 5)
# Jumlah X_test: (2000, 5)
# Jumlah y_train: (8000,)
# Jumlah y_test: (2000,)
#
# ratio y_train (stratified):
# Hantavirus_Positive
# 0    0.742875
# 1    0.257125
# Name: proportion, dtype: float64
#
# ratio y_test (stratified):
# Hantavirus_Positive
# 0    0.743
# 1    0.257
# Name: proportion, dtype: float64

# %% [markdown]
# MODELING==================================================

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier #mengimpor algoritma Decision Tree untuk klasifikasi
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix #mengimpor metrik evaluasi model
import matplotlib.pyplot as plt #mengimpor matplotlib untuk visualisasi grafik
import seaborn as sns #mengimpor seaborn untuk visualisasi statistik

model_decision_tree = DecisionTreeClassifier(random_state=42) #membuat objek model Decision Tree dengan random_state=42
model_decision_tree.fit(X_train, y_train) #melatih model dengan data training

y_pred_dt = model_decision_tree.predict(X_test) #memprediksi kelas target pada data testing dengan model yang telah dilatih

print(classification_report(y_test, y_pred_dt, digits=5))

cm_dt = confusion_matrix(y_test, y_pred_dt)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_dt, annot=True,fmt = 'd')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
# Out:
#               precision    recall  f1-score   support
#
#            0    0.99798   0.99865   0.99832      1486
#            1    0.99610   0.99416   0.99513       514
#
#     accuracy                        0.99750      2000
#    macro avg    0.99704   0.99641   0.99672      2000
# weighted avg    0.99750   0.99750   0.99750      2000
# Text(45.722222222222214, 0.5, 'Aktual')

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier #mengimpor algoritma K-Nearest Neighbors untuk klasifikasi
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix #mengimpor metrik evaluasi model
import matplotlib.pyplot as plt #mengimpor matplotlib untuk visualisasi grafik
import seaborn as sns #mengimpor seaborn untuk visualisasi statistik

model_KNN = KNeighborsClassifier(n_neighbors=5)
model_KNN.fit(X_train,y_train)

y_pred_knn = model_KNN.predict(X_test)

print(classification_report(y_test, y_pred_knn, digits=5))
cm_knn = confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(6,5))
sns.heatmap(cm_knn, annot = True, fmt = 'd')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
# Out:
#               precision    recall  f1-score   support
#
#            0    0.99665   1.00000   0.99832      1486
#            1    1.00000   0.99027   0.99511       514
#
#     accuracy                        0.99750      2000
#    macro avg    0.99832   0.99514   0.99672      2000
# weighted avg    0.99751   0.99750   0.99750      2000
# Text(45.722222222222214, 0.5, 'Aktual')

# %% [markdown]
# XGBoost

# %%
from xgboost import XGBClassifier #mengimpor algoritma XGBoost Classifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix #mengimpor metrik evaluasi model
import matplotlib.pyplot as plt #mengimpor matplotlib untuk visualisasi grafik
import seaborn as sns #mengimpor seaborn untuk visualisasi statistik
model_xgb = XGBClassifier(random_state = 42, use_label_encoder = False, eval_metric = 'logloss')

model_xgb.fit(X_train, y_train)

y_pred_xgb = model_xgb.predict(X_test)

print(classification_report(y_test, y_pred_xgb, digits=5))
cm_xgb = confusion_matrix(y_test, y_pred_xgb)
plt.figure(figsize=(6,5))
sns.heatmap(cm_xgb, annot = True, fmt = 'd')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [09:01:09] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#               precision    recall  f1-score   support
#
#            0    0.99933   0.99933   0.99933      1486
#            1    0.99805   0.99805   0.99805       514
#
#     accuracy                        0.99900      2000
#    macro avg    0.99869   0.99869   0.99869      2000
# weighted avg    0.99900   0.99900   0.99900      2000

# %% [markdown]
# Pemilihan Model Terbaik

# %%
recall_dtc_class1 = recall_score(y_test, y_pred_dt, pos_label=1) #menghitung recall kelas 1 untuk model Decision Tree
recall_knn_class1 = recall_score(y_test, y_pred_knn, pos_label=1) #menghitung recall kelas 1 untuk model KNN
recall_xgb_class1 = recall_score(y_test, y_pred_xgb, pos_label=1) #menghitung recall kelas 1 untuk model XGBoost

print("Recall for Class 1 (Hantavirus_Positive=1) for each model:") #menampilkan teks informasi recall kelas 1

print(f"Decision Tree Classifier: {recall_dtc_class1:.4f}") #menampilkan nilai recall kelas 1 model Decision Tree
print(f"K-Nearest Neighbors:      {recall_knn_class1:.4f}") #menampilkan nilai recall kelas 1 model KNN
print(f"XGBoost Classifier:       {recall_xgb_class1:.4f}") #menampilkan nilai recall kelas 1 model XGBoost
# Out:
# Recall for Class 1 (Hantavirus_Positive=1) for each model:
# Decision Tree Classifier: 0.9942
# K-Nearest Neighbors:      0.9903
# XGBoost Classifier:       0.9981

# %% [markdown]
# Hyperparameter Tuning XGBoost

# %%
from xgboost import XGBClassifier #mengimpor algoritma XGBoost Classifier
from sklearn.model_selection import GridSearchCV #mengimpor GridSearchCV untuk mencari hyperparameter terbaik
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix #mengimpor metrik evaluasi model
import matplotlib.pyplot as plt #mengimpor matplotlib untuk visualisasi grafik
import seaborn as sns #mengimpor seaborn untuk visualisasi statistik

param_grid = {
    'n_estimators': [100, 200, 300], #menentukan jumlah boosting rounds yang akan diuji
    'learning_rate': [0.01, 0.1, 0.2], #menentukan learning rate yang akan diuji
    'max_depth': [3, 5, 7], #menentukan kedalaman maksimum pohon keputusan
    'colsample_bytree': [0.7, 0.8, 1.0], #menentukan proporsi fitur yang digunakan tiap tree
    'gamma': [0, 0.1, 0.2] #menentukan minimum loss reduction untuk split node
}

grid_search = GridSearchCV(
    estimator=model_xgb, #model yang akan dituning
    param_grid=param_grid, #kombinasi hyperparameter yang akan diuji
    scoring='recall', #menggunakan recall sebagai metrik evaluasi utama
    cv=3, #menggunakan 3-fold cross validation
    verbose=1, #menampilkan proses training
    n_jobs=-1 #menggunakan seluruh core CPU yang tersedia
)

grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
print(f"\nBest Hyperparameters found: {best_params}")
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
#
# Best Hyperparameters found: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100}
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [09:16:57] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
model_xgb_tuned = XGBClassifier(random_state = 42, use_label_encoder = False, eval_metric = 'logloss', **best_params)
model_xgb_tuned.fit(X_train, y_train)
y_pred_xgb_tuned = model_xgb_tuned.predict(X_test)

print(classification_report(y_test, y_pred_xgb_tuned, digits=5))

cm_xgb = confusion_matrix(y_test, y_pred_xgb_tuned)
plt.figure(figsize=(6,5))
sns.heatmap(cm_xgb, annot = True, fmt = 'd')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [09:19:51] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#               precision    recall  f1-score   support
#
#            0    0.99933   0.99933   0.99933      1486
#            1    0.99805   0.99805   0.99805       514
#
#     accuracy                        0.99900      2000
#    macro avg    0.99869   0.99869   0.99869      2000
# weighted avg    0.99900   0.99900   0.99900      2000
# Text(45.722222222222214, 0.5, 'Aktual')

# %% [markdown]
# Tabel Ringkasan seluruh Model

# %%
tabel_ringkasan = pd.DataFrame({
    'Model': ['Decision Tree', 'K-Nearest Neighbors', 'XGBoost', 'XGBoost Tuned'],
    'Recall (Class 1)': [recall_dtc_class1, recall_knn_class1, recall_xgb_class1, recall_score(y_test, y_pred_xgb_tuned, pos_label=1)]})

print(tabel_ringkasan)
# Out:
#                  Model  Recall (Class 1)
# 0        Decision Tree          0.994163
# 1  K-Nearest Neighbors          0.990272
# 2              XGBoost          0.998054
# 3        XGBoost Tuned          0.998054

# %% [markdown]
# FEATURE SELECTION LANJUT=====================================

# %% [markdown]
# 3 Fitur Terbaik

# %%
df_3fitur = df_standarisasi[['CRP_mg/L','Creatinine_mg/dL','ALT_U/L']]
df_3fitur
# Out:
#       CRP_mg/L  Creatinine_mg/dL   ALT_U/L
# 0    -0.598093         -1.116831 -0.694248
# 1    -0.496937         -0.494596 -0.984245
# 2    -0.752514         -0.210532 -0.934884
# 3    -0.588319         -0.629864 -0.472122
# 4     2.877367          1.832022  0.033832
# ...        ...               ...       ...
# 9995 -0.306842         -1.143884 -0.401165
# 9996 -0.589785         -0.251112  0.089364
# 9997 -0.616662         -0.048210  0.055428
# 9998 -0.278499         -0.859821 -0.160528
# 9999 -0.480810         -0.359327  0.737231
#
# [10000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(df_3fitur, df['Hantavirus_Positive'], test_size=0.2, random_state=42,stratify= df_y)

# %%
model_xgb_tuned_3 = XGBClassifier(random_state = 42, use_label_encoder = False, eval_metric = 'logloss', **best_params)
model_xgb_tuned_3.fit(X_train_3, y_train_3)
y_pred_xgb_tuned_3 = model_xgb_tuned_3.predict(X_test_3)

print(classification_report(y_test_3, y_pred_xgb_tuned_3, digits=5))

cm_xgb3 = confusion_matrix(y_test_3, y_pred_xgb_tuned_3)
plt.figure(figsize=(6,5))
sns.heatmap(cm_xgb3, annot = True, fmt = 'd')

plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [09:37:35] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#               precision    recall  f1-score   support
#
#            0    1.00000   0.99865   0.99933      1486
#            1    0.99612   1.00000   0.99806       514
#
#     accuracy                        0.99900      2000
#    macro avg    0.99806   0.99933   0.99869      2000
# weighted avg    0.99900   0.99900   0.99900      2000

# %% [markdown]
# 2 Fitur Terbaik

# %%
df_2fitur = df_standarisasi[['CRP_mg/L','Creatinine_mg/dL']]
df_2fitur
# Out:
#       CRP_mg/L  Creatinine_mg/dL
# 0    -0.598093         -1.116831
# 1    -0.496937         -0.494596
# 2    -0.752514         -0.210532
# 3    -0.588319         -0.629864
# 4     2.877367          1.832022
# ...        ...               ...
# 9995 -0.306842         -1.143884
# 9996 -0.589785         -0.251112
# 9997 -0.616662         -0.048210
# 9998 -0.278499         -0.859821
# 9999 -0.480810         -0.359327
#
# [10000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(df_2fitur, df['Hantavirus_Positive'], test_size=0.2, random_state=42,stratify = df_y)

# %%
model_xgb_tuned_2 = XGBClassifier(random_state = 42, use_label_encoder = False, eval_metric = 'logloss', **best_params)
model_xgb_tuned_2.fit(X_train_2, y_train_2)
y_pred_xgb_tuned_2 = model_xgb_tuned_2.predict(X_test_2)

print(classification_report(y_test_2, y_pred_xgb_tuned_2, digits=5))

cm_xgb2 = confusion_matrix(y_test_2, y_pred_xgb_tuned_2)
plt.figure(figsize=(6,5))
sns.heatmap(cm_xgb2, annot = True, fmt = 'd')

plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [09:42:13] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#               precision    recall  f1-score   support
#
#            0    0.99664   0.99865   0.99765      1486
#            1    0.99609   0.99027   0.99317       514
#
#     accuracy                        0.99650      2000
#    macro avg    0.99636   0.99446   0.99541      2000
# weighted avg    0.99650   0.99650   0.99650      2000
